# %%
import pandas as pd 
import numpy as np
# %matplotlib inline

# %%
#READ THE FILE
data=pd.read_csv("police_department_data.csv")
data
# Out:
#         incident_id        category  \
# 0         120058272     WEAPON LAWS
# 1         120058272     WEAPON LAWS
# 2         141059263        WARRANTS
# 3         160013662    NON-CRIMINAL
# 4         160002740    NON-CRIMINAL
# ...             ...             ...
# 150495    161061000         ASSAULT
# 150496    176000742    NON-CRIMINAL
# 150497    176000758   LARCENY/THEFT
# 150498    176000764   LARCENY/THEFT
# 150499    179002868  OTHER OFFENSES
#
#                                         crime_description  \
# 0                               POSS OF PROHIBITED WEAPON
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2                                          WARRANT ARREST
# 3                                           LOST PROPERTY
# 4                                           LOST PROPERTY
# ...                                                   ...
# 150495                                            BATTERY
# ...

# %%
#how to analyze data frames?
data.head()
# Out:
#    incident_id      category                               crime_description  \
# 0    120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1    120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2    141059263      WARRANTS                                  WARRANT ARREST
# 3    160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4    160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#             crime_date department_district      resolution  \
# 0  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 1  2016-01-29 11:00:00            SOUTHERN  ARREST, BOOKED
# 2  2016-04-25 14:59:00             BAYVIEW  ARREST, BOOKED
# 3  2016-01-05 23:50:00          TENDERLOIN            NONE
# 4  2016-01-01 00:30:00             MISSION            NONE
#
#                   address   department_id  \
# 0  800 Block of BRYANT ST  12005827212120
# 1  800 Block of BRYANT ST  12005827212168
# ...

# %%
#this attibutes provides the index of the dataframes
data.index
# Out:
# RangeIndex(start=0, stop=150500, step=1)

# %%
data['crime_date'].unique()
# Out:
# array(['2016-01-29 11:00:00', '2016-04-25 14:59:00',
#        '2016-01-05 23:50:00', ..., '2016-10-02 18:25:00',
#        '2016-10-09 21:15:00', '2016-12-30 21:01:00'], dtype=object)

# %%
print(f'{data.memory_usage().sum() /1024**2}MB')
# Out:
# 10.334136962890625MB

# %%
pd.value_counts(data['location'])[:10]
# Out:
# (37.775420706711, -122.403404791479)     3536
# (37.7564864109309, -122.406539115148)     625
# (37.7841893501425, -122.407633520742)     624
# (37.7850629421661, -122.406520987144)     513
# (37.7650501214668, -122.419671780296)     494
# (37.7725405391593, -122.466204667893)     448
# (37.7285280627465, -122.475647460786)     429
# (37.7799444052046, -122.414317857881)     419
# (37.7627436601147, -122.421747650463)     364
# (37.7865647607685, -122.407244087032)     328
# Name: location, dtype: int64

# %%
pd.value_counts(data['crime_description'])[:10]
# Out:
# GRAND THEFT FROM LOCKED AUTO             17741
# LOST PROPERTY                             4596
# AIDED CASE, MENTAL DISTURBED              4566
# PETTY THEFT OF PROPERTY                   4416
# MALICIOUS MISCHIEF, VANDALISM             4262
# BATTERY                                   4211
# PETTY THEFT FROM LOCKED AUTO              3994
# STOLEN AUTOMOBILE                         3603
# DRIVERS LICENSE, SUSPENDED OR REVOKED     3376
# WARRANT ARREST                            3089
# Name: crime_description, dtype: int64

# %%
data["crime_description"].unique()
# Out:
# array(['POSS OF PROHIBITED WEAPON',
#        'FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE', 'WARRANT ARREST',
#        'LOST PROPERTY', 'BATTERY', 'PAROLE VIOLATION', 'FIRE REPORT',
#        'FOUND PERSON', 'ATTEMPTED THEFT FROM LOCKED VEHICLE',
#        'AIDED CASE, MENTAL DISTURBED', 'RESISTING ARREST',
#        'AGGRAVATED ASSAULT WITH A GUN',
#        'BURGLARY,STORE UNDER CONSTRUCTION, FORCIBLE ENTRY',
#        'STOLEN CHECKS, POSSESSION', 'ROBBERY, ARMED WITH A KNIFE',
#        'BATTERY WITH SERIOUS INJURIES', 'PETTY THEFT SHOPLIFTING',
#        'FRAUDULENT USE OF AUTOMATED TELLER CARD',
#        'POSSESSION OF NARCOTICS PARAPHERNALIA', 'PROBATION VIOLATION',
#        'THREATS AGAINST LIFE', 'VIOLATION OF STAY AWAY ORDER',
#        'LOST/STOLEN LICENSE PLATE', 'BURGLARY, VEHICLE (ARREST MADE)',
#        'TRAFFIC VIOLATION ARREST', 'AIDED CASE', 'STOLEN TRUCK',
#        'STOLEN AUTOMOBILE', 'AGGRAVATED ASSAULT WITH A KNIFE',
# ...
